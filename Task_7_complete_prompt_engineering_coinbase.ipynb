# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephBigDataAnalytics/JKaremera-Programming-BigDataAnalytics/blob/main/Task_7_complete_prompt_engineering_coinbase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 7

# %% [markdown]
# Executive Summary – Evaluation of Coinbase’s Q3 2024 Strategy
#
# As of Q3 2024, evidence suggests that Coinbase’s strategic shift to reduce reliance on volatile trading fees is showing early signs of effectiveness, though challenges remain. Evaluations using multiple prompting techniques highlight a consistent understanding of Coinbase’s strategy, with the Chain-of-Thought approach scoring highest (89/100), reflecting strong comprehension, effective use of evidence, robust financial reasoning, and a clear, balanced conclusion. This approach emphasized Coinbase’s diversification into subscription services, staking, and institutional offerings as mitigants against fluctuating trading revenue.
#
# Other techniques—Role-Playing (83), Contrastive (79), and Few-Shot (73)—also identified strategic strengths but showed weaker evidence integration and comparative context, suggesting some analysts struggle to contextualize Coinbase’s performance relative to industry peers. Overall, metrics indicate that while trading fees remain a significant revenue component, the firm is gradually stabilizing its revenue streams through alternative products.
#
# In conclusion, Coinbase’s strategy is partially succeeding: the company demonstrates tangible progress toward revenue diversification, with analytical evaluations supporting cautious optimism. Continued monitoring of subscription growth and institutional engagement will be essential to determine whether the strategy can sustain long-term resilience against market volatility.

# %% [markdown]
# This is a copy of a conversation between ChatGPT & me.
#
# Report conversation
# Coinbase earnings call transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# Construct four different prompting techniques for the following:
# The Base Question: "Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?"
#
# Here are four distinct prompting techniques you can use to analyze the question:
#
# Base Question:
# “Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?”
#
# I’ll structure each prompt style so you can directly paste it into an LLM or research workflow.
#
# 1️⃣ Chain-of-Thought Prompting (Step-by-Step Analytical)
# Purpose: Force structured reasoning about financial data and strategy.
#
# Prompt Template
#
# Read the Q3 2024 earnings call transcript of Coinbase Global.
#
# Answer the question: Is Coinbase's strategy to reduce reliance on volatile trading fees working as of Q3 2024?
#
# Follow these steps:
#
# Identify Coinbase’s stated strategy to diversify revenue.
#
# Extract data on:
#
# Transaction revenue
#
# Subscription & services revenue
#
# Total revenue mix
#
# Compare Q3 2024 results to prior periods.
#
# Evaluate whether diversification improved stability.
#
# Conclude with a Yes/No/Partially answer with evidence.
#
# Why it works
#
# Forces reasoning instead of vague answers.
#
# Ensures financial metrics are cited.
#
# Key Data Example from Transcript
#
# Coinbase aimed to “diversify revenue… away from transaction fee revenue” and was on pace to exceed $2 billion in subscription & services revenue in 2024.
#
# 2️⃣ Role-Playing Prompting (Perspective-Driven)
# Purpose: Get expert-style interpretation.
#
# Prompt Template
#
# You are a senior equity research analyst at an investment bank.
#
# Using the Q3 2024 earnings call of Coinbase Global, write a short research note answering:
# Is Coinbase’s strategy to reduce reliance on volatile trading fees working?
#
# Include:
#
# Investment thesis
#
# Key metrics
#
# Risks
#
# Final rating (Positive / Neutral / Negative)
#
# Why it works
#
# Produces realistic investment-style conclusions.
#
# Encourages synthesis of qualitative + quantitative info.
#
# 3️⃣ Few-Shot Prompting (With Examples)
# Purpose: Teach the model what a good answer looks like.
#
# Prompt Template
#
# Here are examples of evaluating diversification strategies:
#
# Example 1:
# Company A shifted revenue from ads to subscriptions. Subscription share rose from 10%→40%, reducing volatility → Strategy working.
#
# Example 2:
# Company B tried diversification but new revenue stayed small → Strategy not working.
#
# Now analyze Coinbase Global using its Q3 2024 earnings call transcript.
#
# Determine if its strategy to reduce reliance on trading fees is working. Provide reasoning.
#
# Why it works
#
# Aligns the model’s evaluation method.
#
# Good for consistent outputs across companies.
#
# 4️⃣ Contrastive Prompting (Compare Two Scenarios)
# Purpose: Evaluate success by comparing expectations vs reality.
#
# Prompt Template
#
# Based on the Q3 2024 earnings call of Coinbase Global, compare:
#
# Scenario A: If Coinbase’s diversification strategy were working.
# Scenario B: If it were not working.
#
# Evaluate actual data vs both scenarios and conclude which is closer.
#
# Why it works
#
# Helps avoid confirmation bias.
#
# Encourages balanced judgment.
#
# 📊 What the Transcript Actually Suggests (Quick Answer)
# From Q3 2024 results:
#
# Coinbase emphasized shifting toward subscription & services revenue.
#
# On pace to exceed $2B in that category.
#
# Transaction revenue still fell 27% QoQ, showing ongoing volatility.
#
# 👉 Interpretation:
#
# Partially working.
#
# Diversification is growing, but trading fees still dominate and remain volatile.
#
# 📈 Revenue Mix Concept (Visual Context)
#
# https://www.capitaliq.spglobal.com/Articles/432026719.png
#
# https://api.backlinko.com/app/uploads/2025/09/coinbase-subscription-services-revenue.png
#
# https://cdn.statcdn.com/Statistic/1225000/1228390-blank-754.png
# 4
# These illustrate the shift from pure trading revenue to stable sources like:
#
# Staking
#
# Custody
#
# USDC stablecoin income
#
# Coinbase One subscriptions
#
# ✅ Summary
# Prompting Method	Best Use Case
# Chain-of-Thought	Deep financial analysis
# Role-Playing	Investment research notes
# Few-Shot	Consistent evaluation across companies
# Contrastive	Balanced decision-making
# If you want, I can also generate actual model answers using each prompt so you can compare output quality.
#
#
#
# Sources
#
# Generate model answers to each prompt using the available earnings call transcript
#
# Below are model answers generated using each of the four prompting techniques, based on the Q3 2024 earnings call transcript of Coinbase Global.
#
# 1️⃣ Chain-of-Thought Model Answer
# Step 1 — Stated Strategy
# Coinbase repeatedly emphasized reducing reliance on transaction fees by growing subscription & services revenue, including staking, custody, USDC income, and Coinbase One.
#
# Step 2 — Key Data
# Subscription & services revenue expected to exceed $2 billion in 2024.
#
# Transaction revenue fell about 27% QoQ, reflecting continued volatility.
#
# Subscription revenue became a larger share of total revenue than in prior years.
#
# Step 3 — Comparison to Prior Periods
# Compared to 2022–2023, subscription revenue is a meaningfully larger portion of total revenue, showing progress.
#
# Step 4 — Stability Assessment
# Although diversification revenue is growing, trading revenue still dominates total results and remains sensitive to crypto market activity.
#
# Conclusion
# Answer: Partially working.
# Coinbase has materially grown non-trading revenue, but the company still depends heavily on trading fees.
#
# 2️⃣ Role-Playing Model Answer (Equity Analyst Note)
# Investment Thesis
# Coinbase is executing on its strategy to diversify revenue through subscription and services, but trading fees remain the primary driver of earnings.
#
# Key Metrics
# Subscription & services on pace for $2B+ annualized revenue.
#
# Transaction revenue declined 27% QoQ.
#
# Subscription share of revenue increasing.
#
# Risks
# Crypto price cycles still drive trading volumes.
#
# Stablecoin revenue tied to interest rates.
#
# Regulatory risk in staking/custody.
#
# Analyst View
# The diversification strategy is working incrementally but has not yet transformed Coinbase into a stable revenue business.
#
# Rating
# Neutral — Strategy progressing but not complete.
#
# 3️⃣ Few-Shot Model Answer
# Pattern Comparison
# Example of Success: Company shifts revenue mix significantly and reduces volatility.
# Example of Failure: New revenue streams remain small.
#
# Coinbase Evaluation
# Subscription revenue is growing rapidly and becoming a significant portion of revenue.
#
# However, trading revenue still dominates and fluctuates heavily.
#
# Conclusion
# Coinbase is in the middle stage of diversification.
# The strategy is working but incomplete.
#
# 4️⃣ Contrastive Model Answer
# Scenario A — Strategy Working
# Subscription revenue growing quickly.
#
# Revenue mix shifting away from trading.
#
# Earnings volatility declining.
#
# Scenario B — Strategy Not Working
# Trading still dominates.
#
# Subscription revenue insignificant.
#
# Earnings remain highly volatile.
#
# Actual Results
# Subscription revenue is rising strongly.
#
# Trading revenue still dominates and is volatile.
#
# Verdict
# Reality lies between A and B → Moderately successful but not yet achieved.
#
# ✅ Overall Consensus Across Prompts
# Short Answer:
# 👉 Coinbase’s strategy is working in progress, not fully achieved.
#
# Evidence
#
# Strong growth in subscription & services revenue.
#
# Still heavy reliance on trading fees.
#
# Revenue volatility remains tied to crypto market cycles.
#
# If you’d like, I can also:
#
# Build a financial model of revenue mix trends
#
# Compare Coinbase to Kraken, Binance, or CME crypto futures
#
# Predict when diversification might meaningfully stabilize earnings.
#
#
# Construct a reliable rubric to evaluate these responses and perform analysis
#
# Below is a reliable evaluation rubric for judging answers to the question about Coinbase Global’s diversification strategy, followed by a scored analysis of the four model responses.
#
# This rubric is designed so different reviewers (analysts, students, or LLM evaluators) can produce consistent results.
#
# ✅ Part 1 — Reliable Evaluation Rubric
# 🎯 Goal
# Evaluate whether an answer correctly assesses:
#
# Is Coinbase’s strategy to reduce reliance on volatile trading fees working as of Q3 2024?
#
# 📊 Scoring Categories (Total = 100 points)
# Category	Points	What to Look For
# 1. Understanding of Strategy	15	Identifies Coinbase’s goal to grow subscription & services revenue
# 2. Use of Evidence	20	Includes metrics from transcript (revenue mix, QoQ changes, guidance)
# 3. Financial Reasoning	20	Correct interpretation of revenue mix and volatility implications
# 4. Comparative Context	10	Compares to prior periods or industry norms
# 5. Balanced Judgment	15	Considers both progress and limitations
# 6. Clear Conclusion	10	Gives clear Yes/No/Partial answer
# 7. Communication Quality	10	Clear, structured, concise explanation
# 🧠 Reliability Enhancements
# To make the rubric consistent:
#
# ✔ Anchor Examples
# 90–100: Uses transcript data + nuanced conclusion.
#
# 70–89: Correct reasoning but limited data.
#
# 50–69: Some understanding but weak evidence.
#
# <50: Incorrect or unsupported claims.
#
# ✔ Inter-Rater Checklist
# Reviewers confirm:
#
# Did the answer mention subscription & services revenue?
#
# Did it discuss trading fee volatility?
#
# Did it compare periods?
#
# Did it give a conclusion?
#
# ✅ Part 2 — Analysis of the Four Model Answers
# 1️⃣ Chain-of-Thought Answer
# Score
# Category	Score
# Understanding Strategy	15/15
# Evidence	15/20
# Financial Reasoning	18/20
# Comparative Context	7/10
# Balanced Judgment	15/15
# Clear Conclusion	10/10
# Communication	9/10
# Total = 89/100
#
# Strengths
# Clear step-by-step logic.
#
# Correct “partially working” conclusion.
#
# Mentions key metrics.
#
# Weaknesses
# Could include exact revenue mix percentages.
#
# Limited trend analysis across multiple quarters.
#
# 👉 Verdict: Strong analytical answer.
#
# 2️⃣ Role-Playing Answer
# Score
# Category	Score
# Understanding Strategy	14/15
# Evidence	12/20
# Financial Reasoning	17/20
# Comparative Context	6/10
# Balanced Judgment	14/15
# Clear Conclusion	10/10
# Communication	10/10
# Total = 83/100
#
# Strengths
# Realistic equity analyst style.
#
# Includes risks and thesis.
#
# Weaknesses
# Less quantitative detail.
#
# Less historical comparison.
#
# 👉 Verdict: Good but lighter on data.
#
# 3️⃣ Few-Shot Answer
# Score
# Category	Score
# Understanding Strategy	12/15
# Evidence	10/20
# Financial Reasoning	15/20
# Comparative Context	5/10
# Balanced Judgment	12/15
# Clear Conclusion	10/10
# Communication	9/10
# Total = 73/100
#
# Strengths
# Clear reasoning pattern.
#
# Logical conclusion.
#
# Weaknesses
# Minimal transcript evidence.
#
# Too general.
#
# 👉 Verdict: Adequate but shallow.
#
# 4️⃣ Contrastive Answer
# Score
# Category	Score
# Understanding Strategy	13/15
# Evidence	10/20
# Financial Reasoning	16/20
# Comparative Context	6/10
# Balanced Judgment	15/15
# Clear Conclusion	10/10
# Communication	9/10
# Total = 79/100
#
# Strengths
# Excellent logical framing.
#
# Avoids bias.
#
# Weaknesses
# Still light on quantitative evidence.
#
# 👉 Verdict: Strong reasoning, moderate data support.
#
# ✅ Part 3 — Overall Findings
# Ranking
# Chain-of-Thought — 89
#
# Role-Playing — 83
#
# Contrastive — 79
#
# Few-Shot — 73
#
# Key Insight
# The best answers:
#
# ✔ Use transcript numbers
# ✔ Compare revenue mix over time
# ✔ Acknowerledge partial success
#
# The weaker answers:
#
# ❌ Lack quantitative evidence
# ❌ Don’t compare to prior periods
#
# ✅ Part 4 — Improved “Gold Standard” Answer
# A top-tier answer would include:
#
# % of revenue from subscriptions vs trading
#
# Multi-quarter trend
#
# Discussion of stability vs crypto cycles
#
# Clear conclusion
#
# Example Conclusion
#
# Coinbase’s diversification strategy is working but incomplete as of Q3 2024. Subscription & services revenue is growing rapidly and becoming meaningful, but transaction fees remain the dominant and volatile revenue source.
#
# ✅ Part 5 — How to Use This Rubric
# You can apply it to:
#
# LLM benchmarking
#
# Analyst training
#
# Earnings-call research workflows
#
# Prompt engineering evaluation
#
# If you’d like, I can next:
#
# ✔ Build an automated scoring prompt
# ✔ Compare Coinbase to Kraken or CME
# ✔ Create a spreadsheet scoring template
# ✔ Evaluate another earnings call using the same rubric.
#
#
# Can you combine the scores of each prompt into a single table
#
# Here is a single consolidated scoring table combining all rubric results for the four prompting techniques.
#
# 📊 Combined Evaluation Table
# Prompting Technique	Understanding Strategy (15)	Evidence Use (20)	Financial Reasoning (20)	Comparative Context (10)	Balanced Judgment (15)	Clear Conclusion (10)	Communication (10)	Total Score (100)
# Chain-of-Thought	15	15	18	7	15	10	9	89
# Role-Playing	14	12	17	6	14	10	10	83
# Contrastive	13	10	16	6	15	10	9	79
# Few-Shot	12	10	15	5	12	10	9	73
# 🏆 Ranking
# Chain-of-Thought — 89
#
# Role-Playing — 83
#
# Contrastive — 79
#
# Few-Shot — 73
#
# 📌 Interpretation
# Best Overall: Chain-of-Thought → strongest evidence use + structured reasoning.
#
# Best Real-World Style: Role-Playing → closest to analyst report.
#
# Best Bias Control: Contrastive → balanced evaluation.
#
# Most General: Few-Shot → consistent but shallow.
#
# If you'd like, I can next:
#
# ✔ Create a weighted rubric for investor vs academic use
# ✔ Visualize the scores in a radar chart
# ✔ Automate scoring with an LLM prompt template
# ✔ Compare these prompting methods across multiple earnings calls.
